# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = [0.01,1,100]
y1 = [0.74641,0.7703,0.76076]
x2 = x1
y2 = [,0.76076,]

y3 = [0.025354416575790628, 0.029716466739367453, 0.026717557251908386, 0.028353326063249695, 0.028625954198473247, 0.028080697928026144, 0.02726281352235549, 0.02726281352235549, 0.027808069792802592, 0.028080697928026144]
y4 = [0.049707602339181256, 0.049707602339181256, 0.049707602339181256, 0.052631578947368474, 0.052631578947368474, 0.04678362573099415, 0.04678362573099415, 0.04678362573099415, 0.04678362573099415, 0.04678362573099415]

# plt.plot(x1,y1,"--",label='Unavg Train')
plt.plot(x1,y1,label='Linear')
plt.plot(x1,y2,label='Quadric')
plt.plot(x1,y3,label='Qaussian')
# plt.plot(x1,y4,"--",label='Avg Dev')

plt.ylabel("Error Rate")
plt.xlabel("C")
plt.title("SVM Linear Kernel Training Cross Validation")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()
